# %% [markdown]
# # LOAD DATA TO BRONZE

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine=create_engine("postgresql+psycopg2://user:pass@localhost:5433/etl1_db")
df=pd.read_csv("../data/messy_orders_dataset.csv")
df
# Out:
#      order_id customer_name       city   product quantity  price  order_date  \
# 0         0.0         John      Nakuru   Monitor        2   1000  2025-07-17
# 1         1.0          John     Nakuru   Monitor      two  1,200          ??
# 2         2.0           Pat        NaN  Keyboard        1   2000  2025-10-30
# 3         3.0          Mike    NAIROBI     Phone        3   1500  2026-03-31
# 4         4.0         Sarah   Eldoret      Mouse      two   2000  2026-03-30
# ..        ...           ...        ...       ...      ...    ...         ...
# 115     115.0          John      nyeri   Monitor      two   1500          ??
# 116       NaN         Sarah    Mombasa     PHONE      NaN   1500  2026-02-26
# 117     117.0           Sam   Eldoret      PHONE        1   1000  2025-09-29
# 118     118.0        Chris         NaN     Phone        1   1500  2026-03-20
# 119     119.0           Sam      nyeri    laptop      two  1,200  2025-08-07
#
#          status
# 0     Completed
# ...

# %%
df.to_sql(
    name="orders_raw",
    con=engine,
    schema="bronze",
    if_exists="append",
    index=False
)
# Out:
# 'Success'

# %% [markdown]
# # LOAD DATA TO SILVER LAVER
